# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from llama_index.core import SimpleDirectoryReader

reader = SimpleDirectoryReader(input_files=["/Users/yelopez/git/heimat/medivise-hackathon/data/drug-interactions-book.pdf"])
pages = reader.load_data()

# %%
documents = [doc.to_langchain_format() for doc in pages]
len(documents)
# Out:
# 1473

# %%
filtered_documents = [doc for doc in documents if doc.metadata["page_label"].isdigit()]
len(filtered_documents)
# Out:
# 1464

# %%
raw_docs = [page for page in filtered_documents if 1301 > int(page.metadata["page_label"]) > 10] # skipping content table

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(separator="\n",chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(raw_docs)
print(len(raw_docs), len(documents))
# Out:
# 1290 13757

# %%
documents[0]
# Out:
# Document(page_content='General considerations 11\nTo aid collection of data in this area, health professionals should routine-\nly ask patients about their use of herbal medicines and supplements, and\nreport any unexpected responses to treatment. \nAn additional problem in interpreting these interactions, is that the inter-\nacting constituent of the herb is usually not known and is therefore not\nstandardised for. It could vary widely between different products, and\nbatches of the same product.\nSt John’s wort\nAn increasing number of reports have implicated St John’s wort ( Hyperi-\ncum perforatum ) in drug interactions. Evidence has shown that the herb\ncan induce the cytochrome P450 isoenzyme CYP3A4, and can also induce\n‘P-glycoprotein’, (p.8). Hence St John’s wort decreases the levels of\n‘ciclosporin’, (p.1037) and ‘digoxin’, (p.927), respectively. Other less cer-\ntain evidence suggests that CYP2E1 and CYP1A2 may also be induced.\nSt John’s wort has serotonergic properties, and this has resulted in a phar-', metadata={'page_label': '11', 'file_name': 'drug-interactions-book.pdf', 'file_path': '/Users/yelopez/git/heimat/medivise-hackathon/data/drug-interactions-book.pdf', 'file_type': 'application/pdf', 'file_size': 16090427, 'creation_date': '2024-05-02', 'last_modified_date': '2024-05-02'})

# %%
from langchain_community.embeddings import DatabricksEmbeddings


embeddings = DatabricksEmbeddings(endpoint="databricks-bge-large-en")


query_result = embeddings.embed_query("This is a test document.")
len(query_result)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/medivise-databricks/lib/python3.10/site-packages/pydantic/_internal/_config.py:334: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# 1024

# %%
import os

MONGO_URI = os.getenv("MONGO_URI")
DB_NAME = os.getenv("MONGO_DB")
COLLECTION_NAME = os.getenv("MONGO_COLLECTION_NAME")
ATLAS_VECTOR_SEARCH_INDEX_NAME=os.getenv("ATLAS_VECTOR_SEARCH_INDEX_NAME")

# %%
from pymongo import MongoClient

client = MongoClient(MONGO_URI)

# %%
documents[0:2]
# Out:
# [Document(page_content='General considerations 11\nTo aid collection of data in this area, health professionals should routine-\nly ask patients about their use of herbal medicines and supplements, and\nreport any unexpected responses to treatment. \nAn additional problem in interpreting these interactions, is that the inter-\nacting constituent of the herb is usually not known and is therefore not\nstandardised for. It could vary widely between different products, and\nbatches of the same product.\nSt John’s wort\nAn increasing number of reports have implicated St John’s wort ( Hyperi-\ncum perforatum ) in drug interactions. Evidence has shown that the herb\ncan induce the cytochrome P450 isoenzyme CYP3A4, and can also induce\n‘P-glycoprotein’, (p.8). Hence St John’s wort decreases the levels of\n‘ciclosporin’, (p.1037) and ‘digoxin’, (p.927), respectively. Other less cer-\ntain evidence suggests that CYP2E1 and CYP1A2 may also be induced.\nSt John’s wort has serotonergic properties, and this has resulted in a phar-', metadata={'page_label': '11', 'file_name': 'drug-interactions-book.pdf', 'file_path': '/Users/yelopez/git/heimat/medivise-hackathon/data/drug-interactions-book.pdf', 'file_type': 'application/pdf', 'file_size': 16090427, 'creation_date': '2024-05-02', 'last_modified_date': '2024-05-02'}),
#  Document(page_content='tain evidence suggests that CYP2E1 and CYP1A2 may also be induced.\nSt John’s wort has serotonergic properties, and this has resulted in a phar-\nmacodynamic interaction with the ‘SSRIs’, (p.1224), namely the develop-\nment of the serotonin syndrome. St John’s wort contains many possibleconstituents that could be responsible for its pharmacological effects. The\nmajor active constituents are currently considered to be hyperforin (a\nphloroglucinol) and hypericin (a naphthodianthrone). Hypericin is theonly constituent that is standardised fo r, and then only in some St John’s\nwort preparations.\nGeneral references\n1. Miller LG. Herbal medicinals. Selected clinical considerations focusing on known or potential\ndrug-herb interactions. Arch Intern Med  (1998) 158, 2200–11. \n2. Fugh-Berman A. Herb-drug interactions. Lancet  (2000) 355, 134–8. Correction. ibid. 1020. \n3. Wang Z, Gorski JC, Hamman MA, Huang S-M, Lesko LJ, Hall SD. The effects of St John’s', metadata={'page_label': '11', 'file_name': 'drug-interactions-book.pdf', 'file_path': '/Users/yelopez/git/heimat/medivise-hackathon/data/drug-interactions-book.pdf', 'file_type': 'application/pdf', 'file_size': 16090427, 'creation_date': '2024-05-02', 'last_modified_date': '2024-05-02'})]

# %%
from langchain.vectorstores.mongodb_atlas import MongoDBAtlasVectorSearch

MONGODB_COLLECTION = client[DB_NAME][COLLECTION_NAME]

vector_store = MongoDBAtlasVectorSearch.from_documents(
    documents,
    embeddings,
    collection=MONGODB_COLLECTION,
    index_name=ATLAS_VECTOR_SEARCH_INDEX_NAME,
)

# %%
vector_store.similarity_search("paracetamol")
# Out:
# [Document(page_content='alcohol daily in men and 40 g daily in women).\n23 \nIn a randomised, placebo-controlled study, there was no difference in\nmeasures of hepatotoxicity (mean AST levels, mean INR) between 102 al-\ncoholic patients who received paracetamol 1 g four times daily for 2 days,\nand 99 alcoholic patients who received placebo. In this study, patients hadentered an alcohol detoxification centre, and were given paracetamol im-Alcohol + Orlistat\nAlcohol + Paracetamol (Acetaminophen)', metadata={'_id': ObjectId('663788137ba472d5b7fab4a1'), 'embedding': [0.01251983642578125, 0.00811004638671875, 0.002056121826171875, 0.023529052734375, -0.052093505859375, -0.0372314453125, 0.007320404052734375, 0.01702880859375, -0.031707763671875, 0.0177001953125, 0.039581298828125, -0.05462646484375, 0.01168060302734375, -0.028228759765625, 0.00902557373046875, 0.013763427734375, -0.01293182373046875, -0.056396484375, 0.002124786376953125, 0.0026683807373046875, 0.0102691650390625, 0.03753662109375, -0.05108642578125, 0.0254058837890625, -0.0618896484375, 0.0211639404296875, -0.0283050537109375, -0.0001493692398071289, 0.09710693359375, 0.030181884765625, -0.00044608116149902344, -0.00017535686492919922, 0.0298919677734375, 0.00028967857360839844, 0.02142333984375, -0.027496337890625, 0.02899169921875, -0.00931549072265625, -0.00814056396484375, -0.059600830078125, 0.01910400390625, -0.0005626678466796875, -0.0075531005859375, -0.0169677734375, -0.036224365234375, 0.00981903076171875, -0.046234130859375, -0.0438232421875, -0.01470947265625, 0.0071868896484375, 0.0089874267578125, 0.0010881423950195312, 0.0226593017578125, -0.0153656005859375, 0.0147552490234375, 0.008026123046875, -0.0212860107421875, 0.0113677978515625, -0.039794921875, 0.049285888671875, 0.0132598876953125, 0.0099334716796875, -0.017608642578125, -0.06414794921875, 0.04974365234375, 0.035430908203125, 0.006900787353515625, -0.007595062255859375, 0.01006317138671875, -0.036102294921875, -0.006534576416015625, -0.0134429931640625, -0.0267791748046875, -0.0200958251953125, -0.0275726318359375, 0.0050811767578125, 0.044586181640625, 0.01528167724609375, 0.016693115234375, -0.014495849609375, -0.02752685546875, 0.0462646484375, 0.0192718505859375, -0.00324249267578125, -0.058197021484375, 0.03521728515625, 0.010986328125, 0.040069580078125, 0.00539398193359375, 0.00386810302734375, 0.0107879638671875, 0.023590087890625, -0.038909912109375, -0.01108551025390625, -0.023162841796875, 0.039642333984375, -0.052703857421875, 0.0178375244140625, 0.0028629302978515625, -0.0128631591796875, 0.038482666015625, 0.0205535888671875, 0.0224151611328125, 0.046234130859375, -0.037384033203125, 0.02838134765625, 0.031341552734375, -0.0196533203125, -0.042999267578125, -0.009002685546875, 0.02850341796875, 0.021331787109375, 0.01430511474609375, 0.0110626220703125, 0.0321044921875, -0.00970458984375, -0.00762939453125, 0.01520538330078125, -0.0584716796875, 0.051300048828125, 0.07403564453125, -0.0075531005859375, 0.061614990234375, 0.00951385498046875, 0.0225982666015625, -0.02313232421875, -0.021453857421875, 0.01531219482421875, -0.007770538330078125, -0.07281494140625, 0.005603790283203125, -0.0272674560546875, 0.0266571044921875, 0.0265960693359375, 0.00621795654296875, 0.0279541015625, 0.002155303955078125, 0.0194549560546875, 0.032470703125, -0.032867431640625, -0.0162353515625, 0.0219573974609375, -0.02001953125, 0.06591796875, 0.0142364501953125, 0.056121826171875, 0.0027446746826171875, -0.02813720703125, -0.03631591796875, -0.00922393798828125, -0.036590576171875, 0.018646240234375, -0.0308074951171875, 0.007770538330078125, -0.0099029541015625, 0.004817962646484375, 0.038482666015625, 0.014617919921875, -0.0246124267578125, 0.0028438568115234375, -0.016937255859375, -0.001811981201171875, -0.0229949951171875, 0.03900146484375, -0.035369873046875, 0.04034423828125, -0.033233642578125, 0.038543701171875, 0.007511138916015625, -0.0290069580078125, 0.0589599609375, -0.02642822 ...
#  Document(page_content='racetamol tablet containing sodium bicarbonate: a double-blind, placebo-controlled study inadult patients with acute sore throat. Clin Ther  (2006) 28, 1273–8. \n8. Prescott LF, Yoovathaworn K, Makarananda K, Saivises R, Sriwatanakul K. Impaired ab-\nsorption of paracetamol in vegetarians. Br J Clin Pharmacol  (1993) 36, 237–40. \n9. Stillings M, Havlik I, Chetty M, Clinton C, Sc hall R, Moodley I, Muir N, Little S. Compari-\nson of the pharmacokinetic profiles of soluble aspirin and solid paracetamol tablets in fed andfasted volunteers. Curr Med Res Opin  (2000) 16, 115–24. \n10. Whitcomb DC, Block GD. Association of acet aminophen hepatotoxicity with fasting and eth-\nanol use. JAMA  (1994) 272, 1845–50. \n11. Schenker S, Speeg KV, Perez A, Finch J. The effects of food restriction in man on hepatic\nmetabolism of acetaminophen. Clin Nutr  (2001) 20, 145–50. \n12. Pantuck EJ, Pantuck CB, Anderson KE, Watte nberg LW, Conney AH, Kappas A. Effect of', metadata={'_id': ObjectId('6637884e7ba472d5b7fab9c4'), 'embedding': [-0.01377105712890625, 0.01436614990234375, 0.006500244140625, 0.0355224609375, -0.043243408203125, -0.0260772705078125, 0.01371002197265625, 0.048858642578125, 0.00360870361328125, 0.034759521484375, 0.0141448974609375, -0.04241943359375, 0.036102294921875, -0.0236053466796875, 0.007610321044921875, 0.03704833984375, 0.000568389892578125, -0.0266876220703125, -0.004306793212890625, -0.00016129016876220703, -0.00036716461181640625, 0.01055145263671875, -0.04254150390625, 0.0248565673828125, -0.0509033203125, 0.0325927734375, -0.01345062255859375, -0.00954437255859375, 0.07989501953125, 0.0281829833984375, 0.0252227783203125, -0.0197601318359375, 0.03924560546875, -0.0159912109375, 0.007083892822265625, -0.0214996337890625, 0.04632568359375, -0.05291748046875, 0.01073455810546875, -0.03656005859375, 0.0272216796875, -0.0098876953125, -0.015869140625, -0.0340576171875, -0.0258941650390625, -0.0139312744140625, -0.0181732177734375, -0.033355712890625, 0.0007352828979492188, -0.0193328857421875, 0.007007598876953125, -0.0014858245849609375, 0.059661865234375, -0.02789306640625, 0.00803375244140625, 0.0026683807373046875, -7.349252700805664e-05, -0.0208587646484375, -0.03729248046875, 0.034393310546875, 0.0277099609375, 0.019500732421875, 0.0081634521484375, -0.042022705078125, 0.0275421142578125, 0.029571533203125, 0.0012645721435546875, 0.0004284381866455078, -0.00824737548828125, 0.00830841064453125, -0.0025043487548828125, -0.004924774169921875, -0.02569580078125, -0.012969970703125, -0.04620361328125, -0.0281829833984375, 0.022979736328125, -0.0209197998046875, 0.038970947265625, 0.022613525390625, -0.0201873779296875, 0.0269622802734375, 0.03564453125, -0.030548095703125, -0.04107666015625, 0.0379638671875, -0.0105743408203125, 0.0288543701171875, -0.006999969482421875, 0.0254364013671875, 0.0015201568603515625, 0.0284576416015625, -0.040771484375, 0.0020294189453125, -0.0157623291015625, 0.03826904296875, -0.0384521484375, 0.0219573974609375, -0.00787353515625, -0.003513336181640625, 0.04571533203125, 0.0200653076171875, 0.020477294921875, 0.06182861328125, -0.0230560302734375, 0.00995635986328125, 0.0310211181640625, 0.00833892822265625, -0.0182342529296875, 0.0156707763671875, 0.0343017578125, 0.025543212890625, -0.040252685546875, -0.029571533203125, 0.031585693359375, 0.0215911865234375, -0.01328277587890625, 0.022613525390625, -0.04571533203125, 0.016632080078125, 0.0665283203125, -0.0038604736328125, 0.03314208984375, 0.005931854248046875, 0.040130615234375, -0.015289306640625, 0.00653839111328125, 0.0105438232421875, -0.037445068359375, -0.0775146484375, 0.00701141357421875, -0.007381439208984375, -0.005550384521484375, 0.0016498565673828125, 0.0028057098388671875, 0.0469970703125, 0.006633758544921875, 0.0232696533203125, 0.028350830078125, 0.0030307769775390625, -0.003063201904296875, 0.04443359375, -0.039642333984375, 0.0673828125, 0.0023899078369140625, 0.068115234375, -0.005638 ...
#  Document(page_content='doses of acetaminophen on the liver of alcoholic patients: a randomized, double-blind, place-\nbo-controlled trial. Arch Intern Med  (2001) 161, 2247–52. \n25. Dart RC, Kuffner EK, Rumack BH. Treatment of pain or fever with paracetamol (acetami-\nnophen) in the alcoholic patient: a systematic review. Am J Ther  (2000) 7, 123–4. \n26. Melander O, Lidén A, Melander A. Pharmacoki netic interactions of alcohol and acetylsali-\ncylic acid. Eur J Clin Pharmacol  (1995) 48, 151–3. \n27. Sharma SC, Feely J. The influence of aspirin and paracetamol on blood concentrations of al-\ncohol in young adults. Br J Clin Pharmacol (1996) 41, 467P. \n28. Prescott LF. Paracetamol, alcohol and the liver. Br J Clin Pharmacol  (2000) 49, 291–301. \n29. Tanaka E, Yamazaki K, Misawa S. Update: the clinical importance of acetaminophen hepa-\ntotoxicity in non-alcoholic and alcoholic subjects. J Clin Pharm Ther  (2000) 25, 325–32.', metadata={'_id': ObjectId('663788137ba472d5b7fab4ab'), 'embedding': [0.005878448486328125, 0.007778167724609375, 0.021087646484375, 0.0322265625, -0.045013427734375, -0.032135009765625, 0.002857208251953125, 0.018768310546875, -0.0296783447265625, 0.0285491943359375, 0.030975341796875, -0.044921875, 0.0214385986328125, -0.01207733154296875, 0.019012451171875, 0.00727081298828125, 0.0016546249389648438, -0.0316162109375, 0.00469207763671875, 0.01078033447265625, 0.01666259765625, 0.016082763671875, -0.045684814453125, 0.042724609375, -0.046417236328125, 0.0225677490234375, -0.0206298828125, -0.0124664306640625, 0.0738525390625, 0.04736328125, -0.004825592041015625, 0.0010366439819335938, 0.037689208984375, 0.00981903076171875, -0.00641632080078125, -0.03753662109375, 0.031951904296875, -0.044219970703125, -0.0016431808471679688, -0.03753662109375, 0.00829315185546875, -0.01088714599609375, 0.01259613037109375, -0.030731201171875, -0.02899169921875, -0.0024967193603515625, -0.0283660888671875, -0.0208587646484375, 0.019805908203125, -0.0159912109375, 0.0193023681640625, -0.0141143798828125, 0.037109375, -0.01381683349609375, 0.0033168792724609375, 0.0174713134765625, 0.0006289482116699219, -0.004604339599609375, -0.03118896484375, 0.041046142578125, 0.0118865966796875, -0.0020313262939453125, -0.005283355712890625, -0.036529541015625, 0.042266845703125, 0.0200653076171875, 0.01371002197265625, -0.01154327392578125, -0.01020050048828125, 0.0063018798828125, -0.0196380615234375, -0.0220489501953125, -0.048736572265625, 0.00824737548828125, -0.01358795166015625, -0.00408172607421875, 0.0377197265625, -0.01235198974609375, 0.007061004638671875, 0.013427734375, -0.0341796875, 0.060394287109375, 0.0270538330078125, 0.0204010009765625, -0.038238525390625, 0.042266845703125, -0.0016679763793945312, 0.010223388671875, 0.01259613037109375, 0.038177490234375, 0.00428009033203125, 0.03240966796875, -0.04278564453125, -0.01512908935546875, -0.0180511474609375, 0.05462646484375, -0.0411376953125, 0.018951416015625, 0.0094451904296875, -0.0230712890625, 0.044097900390625, 0.0169830322265625, 0.02178955078125, 0.05804443359375, -0.013580322265625, 0.038330078125, 0.01175689697265625, -0.0121002197265625, -0.02545166015625, -0.017181396484375, 0.01016998291015625, 0.0244903564453125, -0.01288604736328125, 0.01495361328125, 0.0243682861328125, 0.005828857421875, -0.0192718505859375, 0.004711151123046875, -0.0513916015625, 0.07177734375, 0.051025390625, 0.01245880126953125, 0.05963134765625, -0.00579833984375, -0.00482177734375, -0.00849151611328125, -0.0130462646484375, 0.031707763671875, -0.03912353515625, -0.0474853515625, -0.0019969940185546875, -0.029327392578125, -0.00768280029296875, 0.0260772705078125, 0.0078887939453125, 0.0166168212890625, 0.01050567626953125, 0.02813720703125, 0.035369873046875, -0.00370025634765625, -0.00897979736328125, 0.0274658203125, -0.0235748291015625, 0.072998046875, 0.01125335693359375, 0.037841796875, -0.0004849433898925781, -0.0274810791015625, -0.021728515625, -0.00832366943359375,  ...
#  Document(page_content='mulation of paracetamol in the renal medulla.\n13 \nA review concluded that the available evidence does not support an\nincreased risk of renal toxicity with the use of combination products of as-\npirin and paracetamol when compared with either drug alone.16 Paraceta-\nmol is often combined with NSAIDs in the management of chronic pain.\nIn addition, paracetamol and ibuprofen  are often used concurrently (as al-\nternating doses) in the management of fever, particularly in children. This\nlatter practice has become controversial. Opponents cite the lack of effica-\ncy data to support combined use (rather than appropriate doses of singleagents), and the theoretical increased risk of overdose and renal toxici-\nty.\n17,18 Others consider that, in the absence of true safety issues, profes-\nsional judgement should be used for recommending combined\ntreatment.19 Further study is clearly needed.\n1. Munsterhjelm E, Niemi TT, Syrjälä MT, Yl ikorkala O, Rosenberg PH. Propacetamol aug-', metadata={'_id': ObjectId('663788387ba472d5b7fab7ed'), 'embedding': [0.0263519287109375, 0.03436279296875, -0.0092926025390625, 0.033538818359375, -0.04071044921875, -0.0166168212890625, -0.00818634033203125, -0.005382537841796875, 0.018951416015625, 0.04339599609375, 0.047515869140625, -0.04327392578125, 0.0233917236328125, 0.01404571533203125, -0.01044464111328125, 0.04010009765625, -0.0021343231201171875, -0.0137786865234375, 0.036224365234375, 0.01450347900390625, 0.0035266876220703125, 0.05267333984375, -0.0195770263671875, -0.01800537109375, -0.022918701171875, 0.03778076171875, -0.027435302734375, -0.0298004150390625, 0.055633544921875, 0.059783935546875, -0.003765106201171875, 0.0076446533203125, 0.0819091796875, 0.01641845703125, -0.009979248046875, -0.0285186767578125, 0.06903076171875, -0.0026912689208984375, 0.0018711090087890625, -0.05426025390625, 0.0205535888671875, 0.006359100341796875, 0.0214080810546875, -0.036102294921875, 0.0008182525634765625, 0.0123291015625, -0.0067596435546875, 0.0028476715087890625, 0.05096435546875, -0.020477294921875, 0.0098724365234375, 0.01422882080078125, 0.01654052734375, -0.02606201171875, -0.017333984375, -0.00382232666015625, 0.0103759765625, 0.0023441314697265625, -0.02117919921875, -0.0035037994384765625, 0.0034236907958984375, -0.008148193359375, 0.00933074951171875, -0.054229736328125, 0.041015625, 0.024749755859375, -0.033050537109375, 0.0118408203125, -0.0069732666015625, 0.0007185935974121094, -0.00833892822265625, 0.0030918121337890625, -0.02825927734375, -0.0264892578125, -0.04583740234375, -0.01284027099609375, 0.015899658203125, -0.018585205078125, 0.036895751953125, 0.0256195068359375, -0.00902557373046875, 0.0572509765625, 0.0215301513671875, -0.026092529296875, -0.01751708984375, 0.024017333984375, -0.055419921875, 0.0157928466796875, 0.002696990966796875, 0.0015554428100585938, 0.01873779296875, 0.026641845703125, -0.0308685302734375, -0.012603759765625, -0.010711669921875, 0.04595947265625, -0.0191650390625, 0.0227508544921875, -0.004608154296875, 0.00531005859375, 0.049102783203125, 0.03863525390625, 0.031219482421875, 0.052520751953125, -0.01010894775390625, 0.0025081634521484375, 0.0095672607421875, -0.032745361328125, -0.02392578125, 0.01226043701171875, 0.022064208984375, 0.024505615234375, -0.0400390625, -0.060333251953125, 0.043426513671875, -0.00705718994140625, -0.025482177734375, 0.006526947021484375, -0.050567626953125, 0.03363037109375, 0.04718017578125, -0.0252532958984375, 0.00994110107421875, -0.01137542724609375, 0.0246734619140625, 0.003444671630859375, -0.021881103515625, 0.028076171875, 0.006618499755859375, -0.04986572265625, -0.00817108154296875, -0.01136016845703125, -0.0217132568359375, 0.046905517578125, 0.0189208984375, 0.04241943359375, 0.034088134765625, 0.032073974609375, 0.048797607421875, -0.004703521728515625, -0.01157379150390625, 0.0200958251953125, -0.01226806640625, 0.05841064453125, 0.0028667449951171875, 0.046661376953125, - ...

# %%
from langchain_community.chat_models import ChatDatabricks
llm = ChatDatabricks(endpoint="databricks-dbrx-instruct")

# %%
llm.invoke("hello!")
# Out:
# AIMessage(content="Hello! How can I assist you today? I'm here to help with any questions or tasks you have. Just let me know what you need.", response_metadata={'prompt_tokens': 226, 'completion_tokens': 30, 'total_tokens': 256}, id='run-c508a444-64c5-4efc-bd43-3692781f90c5-0')

# %%
from langchain.vectorstores.mongodb_atlas import MongoDBAtlasVectorSearch
from langchain_openai import OpenAIEmbeddings


vector_store = MongoDBAtlasVectorSearch.from_connection_string(
    MONGO_URI,
    DB_NAME + "." + COLLECTION_NAME,
    embeddings,
    index_name=ATLAS_VECTOR_SEARCH_INDEX_NAME,
)

retriever = vector_store.as_retriever()

# %%
def remove_metadata(documents):
    return [document.page_content for document in documents]

# %%
import json
from langchain.schema.runnable import RunnablePassthrough
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser


template = """Use the following pieces of context to answer the question at the end. 
The following is information related to medications:
{context}
Based on the context information reply if I can mix the following medications: {medications}

Consider the information provided and tell me if there is evidence that explains why I can't mix the medicines. If there is no information to answer the question reply with "No information available".
Can I mix the medications? Yes or No. If yes, provide a brief explanation for a patient. 
If no, provide a brief explanation for a patient about why the medications can't be mixed.
Return a JSON with the following structure using the keys "can_mix", "explanation":
"""
rag_prompt = PromptTemplate.from_template(template)

rag_chain = (
    {"context": retriever | remove_metadata, "medications": RunnablePassthrough()}
    | rag_prompt
    | llm
    | StrOutputParser()
)

# %%
response_rag = rag_chain.invoke("Warfarin and ibuprofen")
print(response_rag)
# Out:
# {
# "can_mix": "No",
# "explanation": "The information provided indicates that there is a potential interaction between Warfarin and ibuprofen. Combining these medications may increase the risk of bleeding due to the effect of ibuprofen on blood clotting. It is important to consult with your healthcare provider before mixing these medications."
# }

# %%
rag_chain.get_graph().print_ascii()
# Out:
#               +------------------------------------+
#               | Parallel<context,medications>Input |
#               +------------------------------------+
#                       ****               ****
#                    ***                       ***
#                  **                             ***
#   +----------------------+                         **
#   | VectorStoreRetriever |                          *
#   +----------------------+                          *
#               *                                     *
#               *                                     *
#               *                                     *
# +-------------------------+                  +-------------+
# | Lambda(remove_metadata) |                  | Passthrough |
# +-------------------------+                  +-------------+
#                       ****               ****
#                           ***         ***
#                              **     **
#               +-------------------------------------+
#               | Parallel<context,medications>Output |
#               +-------------------------------------+
#                                  *
#                                  *
#                                  *
#                         +----------------+
#                         | PromptTemplate |
#                         +----------------+
#                                  *
#                                  *
#                                  *
#                         +----------------+
#                         | ChatDatabricks |
#                         +----------------+
#                                  *
#                                  *
#                                  *
#                         +-----------------+
#                         | StrOutputParser |
#                         +-----------------+
#                                  *
#                                  *
#                                  *
#                     +-----------------------+
#                     | StrOutputParserOutput |
#                     +-----------------------+

# %%
from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=retriever,
)

# %%
qa_chain.invoke("Warfarin and acetaminophen?")
# Out:
# {'query': 'Warfarin and acetaminophen?',
#  'result': 'I cannot find any information about the interaction between warfarin and acetaminophen in the provided text.'}
